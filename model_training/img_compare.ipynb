# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow.keras.applications import resnet_v2, vgg16, vgg19
# from tensorflow import keras
from tensorflow.keras import layers
# from tensorflow.keras.models import Sequential
from PIL import Image

import os
import pathlib
# Out:
# 2023-11-01 12:19:17.104680: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-01 12:19:17.104721: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-01 12:19:17.104756: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-01 12:19:17.112206: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
data_path = "/home/aiia/daeun/data/generated_img_3"
data_dir = pathlib.Path(data_path)

# %%
img_height =  512
img_width = 128
batch_size = 16

# %%
model = tf.keras.models.load_model('/home/aiia/daeun/data/checkpoint/saved-model-23-0.92.h5')

# %%
# val_ds = tf.keras.utils.image_dataset_from_directory(
#   data_dir,
#   image_size=(img_height, img_width),
#   batch_size=batch_size)

# %%
# tp = 0
# tn = 0
# fp = 0
# fn = 0

# %%
# val_file = np.concatenate([y for x, y in val_ds], axis=0) #val_ds의 class name
# class_names = val_ds.class_names
# print(len(val_file))
# print(class_names)

# plt.figure(figsize=(img_height, img_width))

# %%
for image_file in os.listdir(data_path):
    print(image_file)
# Out:
# 286.jpg
# 461.jpg
# 609.jpg
# 466.jpg
# 446.jpg
# 341.jpg
# 193.jpg
# 351.jpg
# 70.jpg
# 225.jpg
# 512.jpg
# 475.jpg
# 383.jpg
# 424.jpg
# 393.jpg
# 122.jpg
# 553.jpg
# 569.jpg
# 379.jpg
# 0.jpg
# 623.jpg
# 226.jpg
# 55.jpg
# 439.jpg
# 179.jpg
# 107.jpg
# 112.jpg
# 165.jpg
# 88.jpg
# 577.jpg
# 652.jpg
# 263.jpg
# 60.jpg
# 97.jpg
# 606.jpg
# 82.jpg
# 162.jpg
# 574.jpg
# 544.jpg
# 388.jpg
# 494.jpg
# 447.jpg
# 265.jpg
# 678.jpg
# 251.jpg
# 642.jpg
# 368.jpg
# 647.jpg
# 18.jpg
# 443.jpg
# 183.jpg
# 454.jpg
# 288.jpg
# 592.jpg
# 529.jpg
# 160.jpg
# 653.jpg
# 194.jpg
# 628.jpg
# 560.jpg
# 253.jpg
# 675.jpg
# 603.jpg
# 120.jpg
# 274.jpg
# 357.jpg
# 187.jpg
# 502.jpg
# 333.jpg
# 616.jpg
# 690.jpg
# 72.jpg
# 85.jpg
# 3.jpg
# 515.jpg
# 558.jpg
# 23.jpg
# 74.jpg
# 458.jpg
# 105.jpg
# 384.jpg
# 15.jpg
# 163.jpg
# 214.jpg
# 651.jpg
# 477.jpg
# 22.jpg
# 470.jpg
# 680.jpg
# 147.jpg
# 321.jpg
# 116.jpg
# 200.jpg
# 293.jpg
# 575.jpg
# 345.jpg
# 318.jpg
# 361.jpg
# 303.jpg
# 68.jpg
# 250.jpg
# ...

# %%
from keras.preprocessing import image

count = 0
not_1 = []
for image_file in os.listdir(data_path):
    print(image_file)
    img_file_path = os.path.join(data_path, image_file)
    input = Image.open(img_file_path)
    input_arr = image.img_to_array(input)
    input_arr = np.array([input_arr])
    pre = model.predict((input_arr))
    predict = np.argmax(pre)
    if predict != 1:
#         print("not 1: ", image_file)
        not_1.append(image_file)
        count += 1
print(count)

# for images, labels in val_ds: #validation 파일 개수 만큼 반복하기
#   print(labels)
#   predict = model.predict(images)
#   pre = np.argmax(predict)
#   if pre == 0:
#     count += 1
# print(count)
# print(count/len(os.listdir(data_path)))
# print(len(os.listdir(data_path)))
  # if labels == 0 and pre == 0:
  #   tp += 1
  # elif labels == 0 and pre == 1:
  #   fn += 1
  # elif labels == 1 and pre == 0:
  #   fp += 1
  # elif labels == 1 and pre == 1:
  #   tn += 1
# Out:
# 286.jpg
# 2023-11-01 12:19:40.488104: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8600
# 1/1 [==============================] - 3s 3s/step
# 461.jpg
# 1/1 [==============================] - 0s 30ms/step
# 609.jpg
# 1/1 [==============================] - 0s 29ms/step
# 466.jpg
# 1/1 [==============================] - 0s 21ms/step
# 446.jpg
# 1/1 [==============================] - 0s 20ms/step
# 341.jpg
# 1/1 [==============================] - 0s 24ms/step
# 193.jpg
# 1/1 [==============================] - 0s 23ms/step
# 351.jpg
# 1/1 [==============================] - 0s 24ms/step
# 70.jpg
# 1/1 [==============================] - 0s 24ms/step
# 225.jpg
# 1/1 [==============================] - 0s 21ms/step
# 512.jpg
# 1/1 [==============================] - 0s 24ms/step
# 475.jpg
# 1/1 [==============================] - 0s 20ms/step
# 383.jpg
# 1/1 [==============================] - 0s 21ms/step
# 424.jpg
# ...

# %%
not_1.sort()
print(not_1)
# Out:
# ['454.jpg']

# %%
for file in not_1:
    img_dir = data_path + '/' + file
    img_dir = pathlib.Path(img_dir)
    if os.path.isfile(img_dir):
        print(img_dir)
        os.remove(img_dir)
# Out:
# /home/aiia/daeun/data/generated_img_3/454.jpg

# %%
precision = tp / (tp + fp)
recall = tp / (tp + fn)
f1 = 2 * ((recall * precision) / (recall + precision))

print(f1)
print(precision, recall)
